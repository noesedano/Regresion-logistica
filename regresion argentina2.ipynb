# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix, precision_score, accuracy_score

# %%
# 🔹 Cargar dataset
df = pd.read_csv("Argentina_sin_valores_nulos.csv")

# 🔹 Rellenar valores nulos con forward y backward fill
#df = df.fillna(method="bfill")
#df = df.fillna(method="ffill")

# %%
# 🔹 Seleccionar variables para la regresión logística
Vars_Indep = df[['host_is_superhost_num', 'host_identity_verified', 'host_acceptance_rate', 
                 'accommodates', 'bathrooms', 'review_scores_rating', 'review_scores_cleanliness',
                 'availability_365', 'price_dolar', 'availability_90']]
Vars_Dep = df['instant_bookable']

# %%
df['host_acceptance_rate'] = df['host_acceptance_rate'].astype(str).str.replace('%', '', regex=True).astype(float)

# %%
# 🔹 Redefinir variables
X = Vars_Indep
y = Vars_Dep

# %%
# 🔹 Dividir en conjunto de entrenamiento y prueba (70%-30%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=None)

# %%
# 🔹 Escalar los datos

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# 🔹 Definir el modelo de regresión logística
algoritmo = LogisticRegression()

# %%
# 🔹 Entrenar el modelo
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# 🔹 Realizar predicciones
y_pred = algoritmo.predict(X_test)

# %%
# 🔹 Matriz de confusión
matriz = confusion_matrix(y_test, y_pred)
print("🔹 Matriz de Confusión:")
print(matriz)
# Out:
# 🔹 Matriz de Confusión:
# [[6961  228]
#  [3032  412]]

# %%
# 🔹 Calcular precisión, exactitud y sensibilidad del modelo
precision = precision_score(y_test, y_pred, average="binary", pos_label="t")
accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred, average="binary", pos_label="f")

print(f"🔹 Precisión del modelo: {precision:.2f}")
print(f"🔹 Exactitud del modelo: {accuracy:.2f}")
print(f"🔹 Sensibilidad del modelo: {recall:.2f}")
# Out:
# 🔹 Precisión del modelo: 0.64
# 🔹 Exactitud del modelo: 0.69
# 🔹 Sensibilidad del modelo: 0.97

# %%
# 🔹 Convertir variable dicotómica (Ejemplo de adaptación basado en 'class' del Titanic)
# Filtrar solo los valores numéricos antes de convertir
df['host_acceptance_rate'] = pd.to_numeric(df['host_acceptance_rate'], errors='coerce')  # Convierte a float, NaN si falla

df['host_acceptance_rate'] = df['host_acceptance_rate'].apply(lambda x: "Alto" if x > 50 else "Bajo")
df
# Out:
#                  id                                       listing_url  \
# 0      1.150800e+04                https://www.airbnb.com/rooms/11508
# 1      1.422200e+04                https://www.airbnb.com/rooms/14222
# 2      1.507400e+04                https://www.airbnb.com/rooms/15074
# 3      1.669500e+04                https://www.airbnb.com/rooms/16695
# 4      2.006200e+04                https://www.airbnb.com/rooms/20062
# ...             ...                                               ...
# 35438  1.299490e+18  https://www.airbnb.com/rooms/1299485648306594093
# 35439  1.299520e+18  https://www.airbnb.com/rooms/1299517001813200561
# 35440  1.299580e+18  https://www.airbnb.com/rooms/1299576358362489808
# 35441  1.299580e+18  https://www.airbnb.com/rooms/1299583339165257006
# 35442  1.299620e+18  https://www.airbnb.com/rooms/1299621727142175211
#
#          host_id      host_name  host_since            host_location  \
# 0          42762        Candela  01/10/2009             New York, NY
# 1       87710233          María  03/08/2016  Buenos Aires, Argentina
# 2          59338         Monica  02/12/2009              no definido
# 3          64880  Elbio Mariano  21/12/2009  Buenos Aires, Argentina
# 4          75891         Sergio  31/01/2010  Buenos Aires, Argentina
# ...          ...            ...         ...                      ...
# 35438  175441302        Micaela  26/02/2018              no definido
# 35439   53808353         Lucila  08/01/2016  Buenos Aires, Argentina
# 35440  661832573          Clara  12/11/2024  Buenos Aires, Argentina
# 35441  182960400         Magali  07/04/2018                Argentina
# 35442    4365340           Gema  09/12/2012  Buenos Aires, Argentina
#
#        host_response_time host_response_rate host_acceptance_rate  \
# 0      within a few hours               100%                 Alto
# 1          within an hour               100%                 Alto
# 2             sin definir                95%                 Alto
# 3          within an hour               100%                 Alto
# 4          within an hour               100%                 Alto
# ...                   ...                ...                  ...
# 35438      within an hour               100%                 Alto
# 35439      within an hour                98%                 Alto
# 35440        within a day                50%                 Bajo
# 35441  within a few hours                97%                 Alto
# 35442      within an hour               100%                 Alto
#
#       host_is_superhost  ...  review_scores_cleanliness  \
# 0                     t  ...                       4.88
# 1                     f  ...                       4.77
# 2                     f  ...                       4.70
# 3                     f  ...                       4.29
# 4                     f  ...                       4.87
# ...                 ...  ...                        ...
# 35438                 f  ...                       4.70
# 35439                 t  ...                       4.70
# 35440                 f  ...                       4.70
# 35441                 f  ...                       4.70
# 35442                 t  ...                       4.70
#
#        review_scores_checkin  review_scores_communication  \
# 0                       4.93                         4.98
# 1                       4.82                         4.90
# 2                       4.90                         4.90
# 3                       4.83                         4.80
# 4                       4.94                         4.93
# ...                      ...                          ...
# 35438                   4.90                         4.90
# 35439                   4.90                         4.90
# 35440                   4.90                         4.90
# 35441                   4.90                         4.90
# 35442                   4.90                         4.90
#
#       review_scores_location  review_scores_value       license  \
# 0                       4.93                 4.85  air005326gen
# 1                       4.87                 4.75  air005326gen
# 2                       4.90                 4.80  air005326gen
# 3                       4.39                 4.41  air005326gen
# 4                       4.93                 4.79  air005326gen
# ...                      ...                  ...           ...
# 35438                   4.90                 4.80  air005326gen
# 35439                   4.90                 4.80  air005326gen
# 35440                   4.90                 4.80  air005326gen
# 35441                   4.90                 4.80  air005326gen
# 35442                   4.90                 4.80  air005326gen
#
#        instant_bookable calculated_host_listings_count  \
# 0                     f                              1
# 1                     f                              6
# 2                     f                              1
# 3                     t                              9
# 4                     f                              4
# ...                 ...                            ...
# 35438                 t                              3
# 35439                 t                             16
# 35440                 f                              1
# 35441                 f                             19
# 35442                 f                              4
#
#       calculated_host_listings_count_entire_homes  reviews_per_month
# 0                                               1               0.28
# 1                                               6               0.81
# 2                                               0               1.40
# 3                                               9               0.27
# 4                                               4               1.83
# ...                                           ...                ...
# 35438                                           3               1.40
# 35439                                          16               1.40
# 35440                                           0               1.40
# 35441                                          19               1.40
# 35442                                           4               1.40
#
# [35443 rows x 52 columns]
